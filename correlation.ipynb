# %%
# Out:
# Dataset:
#     Maths  Science  English
# 0     50       55       40
# 1     60       65       50
# 2     70       75       60
# 3     80       85       70
# 4     90       95       80
#
# Correlation Matrix:
#           Maths  Science  English
# Maths      1.0      1.0      1.0
# Science    1.0      1.0      1.0
# English    1.0      1.0      1.0
